# %%
import os
import sys

sh
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sqlalchemy import text
from ingestion.db import get_engine

engine =  get_engine()
df = pd.read_sql("SELECT * FROM weather_readings ORDER BY timestamp ASC", engine)
print(f"Loaded {len(df)} rows")

df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 6
#       4 import seaborn as sns
#       5 from sqlalchemy import text
# ----> 6 from ingestion.db import get_engine
#       8 engine =  get_engine()
#       9 df = pd.read_sql("SELECT * FROM weather_readings ORDER BY timestamp ASC", engine)
#
# ModuleNotFoundError: No module named 'ingestion'
